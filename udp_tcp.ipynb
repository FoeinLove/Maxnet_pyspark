# %% [markdown]
# # udp_tcp_rate_analysis

# %%
from pyspark.sql.functions import *
d = spark.read.csv('/user/maxnet/iot/tuple/tuple*',sep='\t',header=True)
#d.show(3)

d = d.select(from_unixtime('time').alias('ts'),regexp_replace('mac', ':', '').alias('mac'),'proto','dip','dport').sort('ts',ascending=True).dropna().distinct()
d = d.withColumn('mac1_8',substring(d.mac, 1, 8))
#d.show(truncate=False)

p = spark.read.csv('/user/maxnet/iot/tuple/oui8.csv',header=True)
#p.show(3)

p_sxt = p.filter(p.类型 == '智能摄像头')
p_sxt = p_sxt.drop('term_id','中文名称')

d_sxt = d.join(p_sxt,d.mac1_8 == p_sxt.oui8,how = 'left').distinct().dropna()
#d_sxt.show(3)

ys = d_sxt.filter(d_sxt.brand == '萤石').select('ts','mac','proto','dip','dport').distinct()

# %%
ys.count(),ys.distinct().count()
# Out:
# (266838, 266838)

# %% [markdown]
# ## 私网ip过滤

# %% [raw]
# 私有地址的范围：
#
# A类地址范围：10.0.0.0—10.255.255.255
#
# B类地址范围：172.16.0.0---172.31.255.255
#
# C类地址范围：192.168.0.0---192.168.255.255

# %%
ys = ys.filter(~ys.dip.startswith('10.'))
ys.count()
# Out:
# 266346

# %%
ys.filter(ys.dip.startswith('172')).show(truncate=False)
# Out:
# +-------------------+------------+-----+--------------+-----+
# |ts                 |mac         |proto|dip           |dport|
# +-------------------+------------+-----+--------------+-----+
# |2019-04-06 21:34:10|BC1C8115ABCD|6    |172.45.185.206|33001|
# |2019-04-07 21:17:13|4419B6A770D3|17   |172.25.174.208|10101|
# |2019-04-25 14:37:19|4419B6A770D3|17   |172.23.218.66 |10101|
# +-------------------+------------+-----+--------------+-----+

# %%
ys = ys.filter(~ys.dip.startswith('172.23.'))
ys.count()
# Out:
# 266345

# %%
ys = ys.filter(~ys.dip.startswith('172.25.'))
ys.count()
# Out:
# 266344

# %%
ys = ys.filter(~ys.dip.startswith('192.168.'))
ys.count()
# Out:
# 265481

# %%
ys.select('proto').distinct().show()
# Out:
# +-----+
# |proto|
# +-----+
# |   17|
# |    6|
# |    1|
# +-----+

# %%
ys.select('ts','proto').distinct().count()
# Out:
# 35706

# %%
df = ys.select('ts','proto','dip','dport').distinct()

# %%
df.show(3)
# Out:
# +-------------------+-----+---------------+-----+
# |                 ts|proto|            dip|dport|
# +-------------------+-----+---------------+-----+
# |2019-03-25 15:01:27|   17|183.136.184.150| 6003|
# |2019-03-25 15:01:27|   17|183.136.184.149| 6002|
# |2019-03-25 15:01:27|    6|183.136.184.149| 6002|
# +-------------------+-----+---------------+-----+
# only showing top 3 rows

# %%
df.groupBy('proto').count().show()
# Out:
# +-----+------+
# |proto| count|
# +-----+------+
# |   17|232631|
# |    6| 28165|
# |    1|  4685|
# +-----+------+

# %%
dd = df.dropna().sort('ts',ascending=True)

# %%
w1 = dd.groupBy(window('ts', '1 day'),'proto').count()
w1.sort('window',ascending=True).show(truncate=False)
# Out:
# +------------------------------------------+-----+-----+
# |window                                    |proto|count|
# +------------------------------------------+-----+-----+
# |[2019-03-25 08:00:00, 2019-03-26 08:00:00]|17   |1908 |
# |[2019-03-25 08:00:00, 2019-03-26 08:00:00]|1    |88   |
# |[2019-03-25 08:00:00, 2019-03-26 08:00:00]|6    |730  |
# |[2019-03-26 08:00:00, 2019-03-27 08:00:00]|17   |4370 |
# |[2019-03-26 08:00:00, 2019-03-27 08:00:00]|6    |934  |
# |[2019-03-26 08:00:00, 2019-03-27 08:00:00]|1    |136  |
# |[2019-03-27 08:00:00, 2019-03-28 08:00:00]|6    |529  |
# |[2019-03-27 08:00:00, 2019-03-28 08:00:00]|17   |1219 |
# |[2019-03-27 08:00:00, 2019-03-28 08:00:00]|1    |100  |
# |[2019-03-28 08:00:00, 2019-03-29 08:00:00]|17   |401  |
# |[2019-03-28 08:00:00, 2019-03-29 08:00:00]|1    |36   |
# |[2019-03-28 08:00:00, 2019-03-29 08:00:00]|6    |392  |
# |[2019-03-29 08:00:00, 2019-03-30 08:00:00]|17   |8007 |
# |[2019-03-29 08:00:00, 2019-03-30 08:00:00]|1    |102  |
# |[2019-03-29 08:00:00, 2019-03-30 08:00:00]|6    |508  |
# |[2019-03-30 08:00:00, 2019-03-31 08:00:00]|17   |3574 |
# |[2019-03-30 08:00:00, 2019-03-31 08:00:00]|1    |50   |
# |[2019-03-30 08:00:00, 2019-03-31 08:00:00]|6    |301  |
# |[2019-03-31 08:00:00, 2019-04-01 08:00:00]|17   |3437 |
# |[2019-03-31 08:00:00, 2019-04-01 08:00:00]|1    |102  |
# +------------------------------------------+-----+-----+
# only showing top 20 rows

# %%
w1_tmp = w1.sort('window',ascending=True).filter(w1.proto != '1')
w1_tmp.show(truncate=False)
# Out:
# +------------------------------------------+-----+-----+
# |window                                    |proto|count|
# +------------------------------------------+-----+-----+
# |[2019-03-25 08:00:00, 2019-03-26 08:00:00]|17   |1908 |
# |[2019-03-25 08:00:00, 2019-03-26 08:00:00]|6    |730  |
# |[2019-03-26 08:00:00, 2019-03-27 08:00:00]|17   |4370 |
# |[2019-03-26 08:00:00, 2019-03-27 08:00:00]|6    |934  |
# |[2019-03-27 08:00:00, 2019-03-28 08:00:00]|17   |1219 |
# |[2019-03-27 08:00:00, 2019-03-28 08:00:00]|6    |529  |
# |[2019-03-28 08:00:00, 2019-03-29 08:00:00]|17   |401  |
# |[2019-03-28 08:00:00, 2019-03-29 08:00:00]|6    |392  |
# |[2019-03-29 08:00:00, 2019-03-30 08:00:00]|17   |8007 |
# |[2019-03-29 08:00:00, 2019-03-30 08:00:00]|6    |508  |
# |[2019-03-30 08:00:00, 2019-03-31 08:00:00]|6    |301  |
# |[2019-03-30 08:00:00, 2019-03-31 08:00:00]|17   |3574 |
# |[2019-03-31 08:00:00, 2019-04-01 08:00:00]|6    |500  |
# |[2019-03-31 08:00:00, 2019-04-01 08:00:00]|17   |3437 |
# |[2019-04-01 08:00:00, 2019-04-02 08:00:00]|6    |197  |
# |[2019-04-01 08:00:00, 2019-04-02 08:00:00]|17   |372  |
# |[2019-04-02 08:00:00, 2019-04-03 08:00:00]|6    |630  |
# |[2019-04-02 08:00:00, 2019-04-03 08:00:00]|17   |1034 |
# |[2019-04-03 08:00:00, 2019-04-04 08:00:00]|6    |632  |
# |[2019-04-03 08:00:00, 2019-04-04 08:00:00]|17   |9864 |
# +------------------------------------------+-----+-----+
# only showing top 20 rows

# %%
w1_udp = w1_tmp.sort('window',ascending=True).filter(w1_tmp.proto == '17')
w1_udp.show(truncate=False)
# Out:
# +------------------------------------------+-----+-----+
# |window                                    |proto|count|
# +------------------------------------------+-----+-----+
# |[2019-03-25 08:00:00, 2019-03-26 08:00:00]|17   |1908 |
# |[2019-03-26 08:00:00, 2019-03-27 08:00:00]|17   |4370 |
# |[2019-03-27 08:00:00, 2019-03-28 08:00:00]|17   |1219 |
# |[2019-03-28 08:00:00, 2019-03-29 08:00:00]|17   |401  |
# |[2019-03-29 08:00:00, 2019-03-30 08:00:00]|17   |8007 |
# |[2019-03-30 08:00:00, 2019-03-31 08:00:00]|17   |3574 |
# |[2019-03-31 08:00:00, 2019-04-01 08:00:00]|17   |3437 |
# |[2019-04-01 08:00:00, 2019-04-02 08:00:00]|17   |372  |
# |[2019-04-02 08:00:00, 2019-04-03 08:00:00]|17   |1034 |
# |[2019-04-03 08:00:00, 2019-04-04 08:00:00]|17   |9864 |
# |[2019-04-04 08:00:00, 2019-04-05 08:00:00]|17   |2710 |
# |[2019-04-05 08:00:00, 2019-04-06 08:00:00]|17   |1643 |
# |[2019-04-06 08:00:00, 2019-04-07 08:00:00]|17   |1442 |
# |[2019-04-07 08:00:00, 2019-04-08 08:00:00]|17   |5185 |
# |[2019-04-08 08:00:00, 2019-04-09 08:00:00]|17   |335  |
# |[2019-04-09 08:00:00, 2019-04-10 08:00:00]|17   |2334 |
# |[2019-04-10 08:00:00, 2019-04-11 08:00:00]|17   |21328|
# |[2019-04-11 08:00:00, 2019-04-12 08:00:00]|17   |20071|
# |[2019-04-12 08:00:00, 2019-04-13 08:00:00]|17   |914  |
# |[2019-04-13 08:00:00, 2019-04-14 08:00:00]|17   |683  |
# +------------------------------------------+-----+-----+
# only showing top 20 rows

# %%
w1_tcp = w1_tmp.sort('window',ascending=True).filter(w1_tmp.proto == '6')
w1_tcp.show(truncate=False)
# Out:
# +------------------------------------------+-----+-----+
# |window                                    |proto|count|
# +------------------------------------------+-----+-----+
# |[2019-03-25 08:00:00, 2019-03-26 08:00:00]|6    |730  |
# |[2019-03-26 08:00:00, 2019-03-27 08:00:00]|6    |934  |
# |[2019-03-27 08:00:00, 2019-03-28 08:00:00]|6    |529  |
# |[2019-03-28 08:00:00, 2019-03-29 08:00:00]|6    |392  |
# |[2019-03-29 08:00:00, 2019-03-30 08:00:00]|6    |508  |
# |[2019-03-30 08:00:00, 2019-03-31 08:00:00]|6    |301  |
# |[2019-03-31 08:00:00, 2019-04-01 08:00:00]|6    |500  |
# |[2019-04-01 08:00:00, 2019-04-02 08:00:00]|6    |197  |
# |[2019-04-02 08:00:00, 2019-04-03 08:00:00]|6    |630  |
# |[2019-04-03 08:00:00, 2019-04-04 08:00:00]|6    |632  |
# |[2019-04-04 08:00:00, 2019-04-05 08:00:00]|6    |634  |
# |[2019-04-05 08:00:00, 2019-04-06 08:00:00]|6    |646  |
# |[2019-04-06 08:00:00, 2019-04-07 08:00:00]|6    |688  |
# |[2019-04-07 08:00:00, 2019-04-08 08:00:00]|6    |505  |
# |[2019-04-08 08:00:00, 2019-04-09 08:00:00]|6    |241  |
# |[2019-04-09 08:00:00, 2019-04-10 08:00:00]|6    |727  |
# |[2019-04-10 08:00:00, 2019-04-11 08:00:00]|6    |737  |
# |[2019-04-11 08:00:00, 2019-04-12 08:00:00]|6    |684  |
# |[2019-04-12 08:00:00, 2019-04-13 08:00:00]|6    |700  |
# |[2019-04-13 08:00:00, 2019-04-14 08:00:00]|6    |488  |
# +------------------------------------------+-----+-----+
# only showing top 20 rows

# %%
w1_udp.count(),w1_tcp.count()
# Out:
# (60, 60)

# %%
w1_udp = w1_udp.withColumnRenamed('window','window1').withColumnRenamed('proto','udp').withColumnRenamed('count','udp_count')
w1_tcp = w1_tcp.withColumnRenamed('window','window2').withColumnRenamed('proto','tcp').withColumnRenamed('count','tcp_count')

# %%
udp_tcp = w1_udp.join(w1_tcp,w1_udp.window1==w1_tcp.window2,how='inner')
udp_tcp.show(truncate=False)
# Out:
# +------------------------------------------+---+---------+------------------------------------------+---+---------+
# |window1                                   |udp|udp_count|window2                                   |tcp|tcp_count|
# +------------------------------------------+---+---------+------------------------------------------+---+---------+
# |[2019-04-19 08:00:00, 2019-04-20 08:00:00]|17 |604      |[2019-04-19 08:00:00, 2019-04-20 08:00:00]|6  |462      |
# |[2019-04-30 08:00:00, 2019-05-01 08:00:00]|17 |2586     |[2019-04-30 08:00:00, 2019-05-01 08:00:00]|6  |523      |
# |[2019-03-30 08:00:00, 2019-03-31 08:00:00]|17 |3574     |[2019-03-30 08:00:00, 2019-03-31 08:00:00]|6  |301      |
# |[2019-04-07 08:00:00, 2019-04-08 08:00:00]|17 |5185     |[2019-04-07 08:00:00, 2019-04-08 08:00:00]|6  |505      |
# |[2019-05-22 08:00:00, 2019-05-23 08:00:00]|17 |506      |[2019-05-22 08:00:00, 2019-05-23 08:00:00]|6  |387      |
# |[2019-05-10 08:00:00, 2019-05-11 08:00:00]|17 |4566     |[2019-05-10 08:00:00, 2019-05-11 08:00:00]|6  |340      |
# |[2019-04-28 08:00:00, 2019-04-29 08:00:00]|17 |1174     |[2019-04-28 08:00:00, 2019-04-29 08:00:00]|6  |171      |
# |[2019-04-09 08:00:00, 2019-04-10 08:00:00]|17 |2334     |[2019-04-09 08:00:00, 2019-04-10 08:00:00]|6  |727      |
# |[2019-05-04 08:00:00, 2019-05-05 08:00:00]|17 |2062     |[2019-05-04 08:00:00, 2019-05-05 08:00:00]|6  |529      |
# |[2019-05-18 08:00:00, 2019-05-19 08:00:00]|17 |7231     |[2019-05-18 08:00:00, 2019-05-19 08:00:00]|6  |392      |
# |[2019-05-20 08:00:00, 2019-05-21 08:00:00]|17 |503      |[2019-05-20 08:00:00, 2019-05-21 08:00:00]|6  |369      |
# |[2019-03-26 08:00:00, 2019-03-27 08:00:00]|17 |4370     |[2019-03-26 08:00:00, 2019-03-27 08:00:00]|6  |934      |
# |[2019-04-08 08:00:00, 2019-04-09 08:00:00]|17 |335      |[2019-04-08 08:00:00, 2019-04-09 08:00:00]|6  |241      |
# |[2019-05-16 08:00:00, 2019-05-17 08:00:00]|17 |9976     |[2019-05-16 08:00:00, 2019-05-17 08:00:00]|6  |388      |
# |[2019-05-09 08:00:00, 2019-05-10 08:00:00]|17 |4810     |[2019-05-09 08:00:00, 2019-05-10 08:00:00]|6  |508      |
# |[2019-04-03 08:00:00, 2019-04-04 08:00:00]|17 |9864     |[2019-04-03 08:00:00, 2019-04-04 08:00:00]|6  |632      |
# |[2019-05-08 08:00:00, 2019-05-09 08:00:00]|17 |5120     |[2019-05-08 08:00:00, 2019-05-09 08:00:00]|6  |532      |
# |[2019-05-06 08:00:00, 2019-05-07 08:00:00]|17 |10292    |[2019-05-06 08:00:00, 2019-05-07 08:00:00]|6  |545      |
# |[2019-04-01 08:00:00, 2019-04-02 08:00:00]|17 |372      |[2019-04-01 08:00:00, 2019-04-02 08:00:00]|6  |197      |
# |[2019-04-18 08:00:00, 2019-04-19 08:00:00]|17 |337      |[2019-04-18 08:00:00, 2019-04-19 08:00:00]|6  |252      |
# +------------------------------------------+---+---------+------------------------------------------+---+---------+
# only showing top 20 rows

# %%
udp_tcp = udp_tcp.select('window1','udp','udp_count','tcp','tcp_count')

# %%
udp_tcp = udp_tcp.withColumnRenamed('window1','window').sort('window',ascending=True)
udp_tcp.show(truncate=False)
# Out:
# +------------------------------------------+---+---------+---+---------+
# |window                                    |udp|udp_count|tcp|tcp_count|
# +------------------------------------------+---+---------+---+---------+
# |[2019-03-25 08:00:00, 2019-03-26 08:00:00]|17 |1908     |6  |730      |
# |[2019-03-26 08:00:00, 2019-03-27 08:00:00]|17 |4370     |6  |934      |
# |[2019-03-27 08:00:00, 2019-03-28 08:00:00]|17 |1219     |6  |529      |
# |[2019-03-28 08:00:00, 2019-03-29 08:00:00]|17 |401      |6  |392      |
# |[2019-03-29 08:00:00, 2019-03-30 08:00:00]|17 |8007     |6  |508      |
# |[2019-03-30 08:00:00, 2019-03-31 08:00:00]|17 |3574     |6  |301      |
# |[2019-03-31 08:00:00, 2019-04-01 08:00:00]|17 |3437     |6  |500      |
# |[2019-04-01 08:00:00, 2019-04-02 08:00:00]|17 |372      |6  |197      |
# |[2019-04-02 08:00:00, 2019-04-03 08:00:00]|17 |1034     |6  |630      |
# |[2019-04-03 08:00:00, 2019-04-04 08:00:00]|17 |9864     |6  |632      |
# |[2019-04-04 08:00:00, 2019-04-05 08:00:00]|17 |2710     |6  |634      |
# |[2019-04-05 08:00:00, 2019-04-06 08:00:00]|17 |1643     |6  |646      |
# |[2019-04-06 08:00:00, 2019-04-07 08:00:00]|17 |1442     |6  |688      |
# |[2019-04-07 08:00:00, 2019-04-08 08:00:00]|17 |5185     |6  |505      |
# |[2019-04-08 08:00:00, 2019-04-09 08:00:00]|17 |335      |6  |241      |
# |[2019-04-09 08:00:00, 2019-04-10 08:00:00]|17 |2334     |6  |727      |
# |[2019-04-10 08:00:00, 2019-04-11 08:00:00]|17 |21328    |6  |737      |
# |[2019-04-11 08:00:00, 2019-04-12 08:00:00]|17 |20071    |6  |684      |
# |[2019-04-12 08:00:00, 2019-04-13 08:00:00]|17 |914      |6  |700      |
# |[2019-04-13 08:00:00, 2019-04-14 08:00:00]|17 |683      |6  |488      |
# +------------------------------------------+---+---------+---+---------+
# only showing top 20 rows

# %%
udp_tcp_rate = udp_tcp.withColumn('udp_tcp_rate',round(udp_tcp.udp_count / udp_tcp.tcp_count,2))

# %%
udp_tcp_rate.sort('window',ascending=True).show(60,truncate=False)
# Out:
# +------------------------------------------+---+---------+---+---------+------------+
# |window                                    |udp|udp_count|tcp|tcp_count|udp_tcp_rate|
# +------------------------------------------+---+---------+---+---------+------------+
# |[2019-03-25 08:00:00, 2019-03-26 08:00:00]|17 |1908     |6  |730      |2.61        |
# |[2019-03-26 08:00:00, 2019-03-27 08:00:00]|17 |4370     |6  |934      |4.68        |
# |[2019-03-27 08:00:00, 2019-03-28 08:00:00]|17 |1219     |6  |529      |2.3         |
# |[2019-03-28 08:00:00, 2019-03-29 08:00:00]|17 |401      |6  |392      |1.02        |
# |[2019-03-29 08:00:00, 2019-03-30 08:00:00]|17 |8007     |6  |508      |15.76       |
# |[2019-03-30 08:00:00, 2019-03-31 08:00:00]|17 |3574     |6  |301      |11.87       |
# |[2019-03-31 08:00:00, 2019-04-01 08:00:00]|17 |3437     |6  |500      |6.87        |
# |[2019-04-01 08:00:00, 2019-04-02 08:00:00]|17 |372      |6  |197      |1.89        |
# |[2019-04-02 08:00:00, 2019-04-03 08:00:00]|17 |1034     |6  |630      |1.64        |
# |[2019-04-03 08:00:00, 2019-04-04 08:00:00]|17 |9864     |6  |632      |15.61       |
# |[2019-04-04 08:00:00, 2019-04-05 08:00:00]|17 |2710     |6  |634      |4.27        |
# |[2019-04-05 08:00:00, 2019-04-06 08:00:00]|17 |1643     |6  |646      |2.54        |
# |[2019-04-06 08:00:00, 2019-04-07 08:00:00]|17 |1442     |6  |688      |2.1         |
# |[2019-04-07 08:00:00, 2019-04-08 08:00:00]|17 |5185     |6  |505      |10.27       |
# |[2019-04-08 08:00:00, 2019-04-09 08:00:00]|17 |335      |6  |241      |1.39        |
# |[2019-04-09 08:00:00, 2019-04-10 08:00:00]|17 |2334     |6  |727      |3.21        |
# |[2019-04-10 08:00:00, 2019-04-11 08:00:00]|17 |21328    |6  |737      |28.94       |
# |[2019-04-11 08:00:00, 2019-04-12 08:00:00]|17 |20071    |6  |684      |29.34       |
# |[2019-04-12 08:00:00, 2019-04-13 08:00:00]|17 |914      |6  |700      |1.31        |
# |[2019-04-13 08:00:00, 2019-04-14 08:00:00]|17 |683      |6  |488      |1.4         |
# |[2019-04-14 08:00:00, 2019-04-15 08:00:00]|17 |334      |6  |254      |1.31        |
# |[2019-04-15 08:00:00, 2019-04-16 08:00:00]|17 |601      |6  |477      |1.26        |
# |[2019-04-16 08:00:00, 2019-04-17 08:00:00]|17 |341      |6  |239      |1.43        |
# |[2019-04-17 08:00:00, 2019-04-18 08:00:00]|17 |3606     |6  |463      |7.79        |
# |[2019-04-18 08:00:00, 2019-04-19 08:00:00]|17 |337      |6  |252      |1.34        |
# |[2019-04-19 08:00:00, 2019-04-20 08:00:00]|17 |604      |6  |462      |1.31        |
# |[2019-04-20 08:00:00, 2019-04-21 08:00:00]|17 |332      |6  |234      |1.42        |
# |[2019-04-21 08:00:00, 2019-04-22 08:00:00]|17 |906      |6  |725      |1.25        |
# |[2019-04-22 08:00:00, 2019-04-23 08:00:00]|17 |2025     |6  |635      |3.19        |
# |[2019-04-23 08:00:00, 2019-04-24 08:00:00]|17 |2727     |6  |595      |4.58        |
# |[2019-04-24 08:00:00, 2019-04-25 08:00:00]|17 |2577     |6  |588      |4.38        |
# |[2019-04-25 08:00:00, 2019-04-26 08:00:00]|17 |2691     |6  |388      |6.94        |
# |[2019-04-28 08:00:00, 2019-04-29 08:00:00]|17 |1174     |6  |171      |6.87        |
# |[2019-04-29 08:00:00, 2019-04-30 08:00:00]|17 |2243     |6  |519      |4.32        |
# |[2019-04-30 08:00:00, 2019-05-01 08:00:00]|17 |2586     |6  |523      |4.94        |
# |[2019-05-01 08:00:00, 2019-05-02 08:00:00]|17 |10904    |6  |534      |20.42       |
# |[2019-05-02 08:00:00, 2019-05-03 08:00:00]|17 |3991     |6  |464      |8.6         |
# |[2019-05-03 08:00:00, 2019-05-04 08:00:00]|17 |8378     |6  |505      |16.59       |
# |[2019-05-04 08:00:00, 2019-05-05 08:00:00]|17 |2062     |6  |529      |3.9         |
# |[2019-05-05 08:00:00, 2019-05-06 08:00:00]|17 |2395     |6  |539      |4.44        |
# |[2019-05-06 08:00:00, 2019-05-07 08:00:00]|17 |10292    |6  |545      |18.88       |
# |[2019-05-07 08:00:00, 2019-05-08 08:00:00]|17 |2825     |6  |543      |5.2         |
# |[2019-05-08 08:00:00, 2019-05-09 08:00:00]|17 |5120     |6  |532      |9.62        |
# |[2019-05-09 08:00:00, 2019-05-10 08:00:00]|17 |4810     |6  |508      |9.47        |
# |[2019-05-10 08:00:00, 2019-05-11 08:00:00]|17 |4566     |6  |340      |13.43       |
# |[2019-05-11 08:00:00, 2019-05-12 08:00:00]|17 |324      |6  |249      |1.3         |
# |[2019-05-13 08:00:00, 2019-05-14 08:00:00]|17 |182      |6  |117      |1.56        |
# |[2019-05-14 08:00:00, 2019-05-15 08:00:00]|17 |504      |6  |391      |1.29        |
# |[2019-05-15 08:00:00, 2019-05-16 08:00:00]|17 |527      |6  |369      |1.43        |
# |[2019-05-16 08:00:00, 2019-05-17 08:00:00]|17 |9976     |6  |388      |25.71       |
# |[2019-05-17 08:00:00, 2019-05-18 08:00:00]|17 |39645    |6  |340      |116.6       |
# |[2019-05-18 08:00:00, 2019-05-19 08:00:00]|17 |7231     |6  |392      |18.45       |
# |[2019-05-19 08:00:00, 2019-05-20 08:00:00]|17 |495      |6  |381      |1.3         |
# |[2019-05-20 08:00:00, 2019-05-21 08:00:00]|17 |503      |6  |369      |1.36        |
# |[2019-05-21 08:00:00, 2019-05-22 08:00:00]|17 |1594     |6  |413      |3.86        |
# |[2019-05-22 08:00:00, 2019-05-23 08:00:00]|17 |506      |6  |387      |1.31        |
# |[2019-05-23 08:00:00, 2019-05-24 08:00:00]|17 |595      |6  |389      |1.53        |
# |[2019-05-24 08:00:00, 2019-05-25 08:00:00]|17 |488      |6  |388      |1.26        |
# |[2019-05-25 08:00:00, 2019-05-26 08:00:00]|17 |497      |6  |383      |1.3         |
# |[2019-05-26 08:00:00, 2019-05-27 08:00:00]|17 |306      |6  |242      |1.26        |
# +------------------------------------------+---+---------+---+---------+------------+

# %%
udp_tcp_rate.select('udp_tcp_rate').describe().show()
# Out:
# +-------+------------------+
# |summary|      udp_tcp_rate|
# +-------+------------------+
# |  count|                60|
# |   mean| 8.190333333333331|
# | stddev|15.937704677759601|
# |    min|              1.02|
# |    max|             116.6|
# +-------+------------------+

# %%
ys.count()
# Out:
# 265481

# %% [markdown]
# # mac => 442C051B66E4

# %%
ys.count()
# Out:
# 265481

# %%
ys.show(3)
# Out:
# +-------------------+------------+-----+---------------+-----+
# |                 ts|         mac|proto|            dip|dport|
# +-------------------+------------+-----+---------------+-----+
# |2019-03-25 15:01:27|EC3DFD2CC2A6|   17|183.136.184.150| 6003|
# |2019-03-25 15:01:27|EC3DFD2CC2A6|   17|183.136.184.149| 6002|
# |2019-03-25 15:01:27|EC3DFD2CC2A6|    6|183.136.184.149| 6002|
# +-------------------+------------+-----+---------------+-----+
# only showing top 3 rows

# %%
ys.groupBy('mac').count().sort('count',ascending=False).show()
# Out:
# +------------+------+
# |         mac| count|
# +------------+------+
# |442C051B66E4|136676|
# |BC1C8115ABCD| 94710|
# |EC3DFD2CC2A6| 15390|
# |4419B6A770D3| 13990|
# |BC1C8104ED4B|  4685|
# |E0B94D92067A|    30|
# +------------+------+

# %%
df = ys.filter(ys.mac =='442C051B66E4').select('ts','proto','dip','dport').distinct()

df_tmp = df.filter(df.proto != '1')
dd = df_tmp.groupBy(window('ts', '1 day'),'proto').count()
udp = dd.sort('window',ascending=True).filter(dd.proto == '17')
tcp = dd.sort('window',ascending=True).filter(dd.proto == '6')
udp = udp.withColumnRenamed('window','window1').withColumnRenamed('proto','udp').withColumnRenamed('count','udp_count')
tcp = tcp.withColumnRenamed('window','window2').withColumnRenamed('proto','tcp').withColumnRenamed('count','tcp_count')
udp_tcp = udp.join(tcp,udp.window1 == tcp.window2,how='inner')
udp_tcp = udp_tcp.select('window1','udp','udp_count','tcp','tcp_count')
udp_tcp = udp_tcp.withColumnRenamed('window1','window').sort('window',ascending=True)
udp_tcp_rate = udp_tcp.withColumn('udp_tcp_rate',round(udp_tcp.udp_count / udp_tcp.tcp_count,2))
#udp_tcp_rate.sort('window',ascending=False).show(60,truncate=False)


df_2 = df.groupBy(window('ts', '1 day'),'dport').count()
t1 = df_2.groupBy('window').agg({'dport':'count'})
t1 = t1.withColumnRenamed('window','window1').withColumnRenamed('count(dport)','dport_count')


final = udp_tcp_rate.join(t1,udp_tcp_rate.window == t1.window1,how = 'left')
final = final.select('window','udp', 'udp_count', 'tcp', 'tcp_count', 'udp_tcp_rate','dport_count')
final.sort('window',ascending=False).show(60,truncate=False)
# Out:
# +------------------------------------------+---+---------+---+---------+------------+-----------+
# |window                                    |udp|udp_count|tcp|tcp_count|udp_tcp_rate|dport_count|
# +------------------------------------------+---+---------+---+---------+------------+-----------+
# |[2019-05-26 08:00:00, 2019-05-27 08:00:00]|17 |194      |6  |181      |1.07        |6          |
# |[2019-05-25 08:00:00, 2019-05-26 08:00:00]|17 |312      |6  |290      |1.08        |6          |
# |[2019-05-24 08:00:00, 2019-05-25 08:00:00]|17 |307      |6  |284      |1.08        |5          |
# |[2019-05-23 08:00:00, 2019-05-24 08:00:00]|17 |312      |6  |289      |1.08        |6          |
# |[2019-05-22 08:00:00, 2019-05-23 08:00:00]|17 |312      |6  |288      |1.08        |5          |
# |[2019-05-21 08:00:00, 2019-05-22 08:00:00]|17 |1366     |6  |290      |4.71        |1061       |
# |[2019-05-20 08:00:00, 2019-05-21 08:00:00]|17 |312      |6  |290      |1.08        |6          |
# |[2019-05-19 08:00:00, 2019-05-20 08:00:00]|17 |312      |6  |294      |1.06        |6          |
# |[2019-05-18 08:00:00, 2019-05-19 08:00:00]|17 |4539     |6  |295      |15.39       |4134       |
# |[2019-05-17 08:00:00, 2019-05-18 08:00:00]|17 |39513    |6  |295      |133.94      |30119      |
# |[2019-05-16 08:00:00, 2019-05-17 08:00:00]|17 |9783     |6  |296      |33.05       |8959       |
# |[2019-05-15 08:00:00, 2019-05-16 08:00:00]|17 |310      |6  |286      |1.08        |5          |
# |[2019-05-14 08:00:00, 2019-05-15 08:00:00]|17 |312      |6  |289      |1.08        |6          |
# |[2019-05-13 08:00:00, 2019-05-14 08:00:00]|17 |117      |6  |108      |1.08        |5          |
# |[2019-05-11 08:00:00, 2019-05-12 08:00:00]|17 |196      |6  |179      |1.09        |10         |
# |[2019-05-10 08:00:00, 2019-05-11 08:00:00]|17 |262      |6  |247      |1.06        |6          |
# |[2019-05-09 08:00:00, 2019-05-10 08:00:00]|17 |312      |6  |288      |1.08        |5          |
# |[2019-05-08 08:00:00, 2019-05-09 08:00:00]|17 |3024     |6  |290      |10.43       |2695       |
# |[2019-05-07 08:00:00, 2019-05-08 08:00:00]|17 |1863     |6  |290      |6.42        |1558       |
# |[2019-05-06 08:00:00, 2019-05-07 08:00:00]|17 |9318     |6  |293      |31.8        |8534       |
# |[2019-05-05 08:00:00, 2019-05-06 08:00:00]|17 |312      |6  |295      |1.06        |9          |
# |[2019-05-04 08:00:00, 2019-05-05 08:00:00]|17 |310      |6  |291      |1.07        |8          |
# |[2019-05-03 08:00:00, 2019-05-04 08:00:00]|17 |312      |6  |288      |1.08        |5          |
# |[2019-05-02 08:00:00, 2019-05-03 08:00:00]|17 |312      |6  |288      |1.08        |5          |
# |[2019-05-01 08:00:00, 2019-05-02 08:00:00]|17 |312      |6  |288      |1.08        |5          |
# |[2019-04-30 08:00:00, 2019-05-01 08:00:00]|17 |1632     |6  |289      |5.65        |1326       |
# |[2019-04-29 08:00:00, 2019-04-30 08:00:00]|17 |312      |6  |288      |1.08        |5          |
# |[2019-04-28 08:00:00, 2019-04-29 08:00:00]|17 |117      |6  |108      |1.08        |5          |
# |[2019-04-25 08:00:00, 2019-04-26 08:00:00]|17 |195      |6  |180      |1.08        |5          |
# |[2019-04-24 08:00:00, 2019-04-25 08:00:00]|17 |1884     |6  |290      |6.5         |1577       |
# |[2019-04-23 08:00:00, 2019-04-24 08:00:00]|17 |312      |6  |290      |1.08        |10         |
# |[2019-04-22 08:00:00, 2019-04-23 08:00:00]|17 |1322     |6  |289      |4.57        |1016       |
# |[2019-04-21 08:00:00, 2019-04-22 08:00:00]|17 |312      |6  |288      |1.08        |5          |
# |[2019-04-20 08:00:00, 2019-04-21 08:00:00]|17 |117      |6  |108      |1.08        |5          |
# |[2019-04-19 08:00:00, 2019-04-20 08:00:00]|17 |195      |6  |180      |1.08        |5          |
# |[2019-04-18 08:00:00, 2019-04-19 08:00:00]|17 |117      |6  |108      |1.08        |5          |
# |[2019-04-17 08:00:00, 2019-04-18 08:00:00]|17 |1772     |6  |183      |9.68        |1581       |
# |[2019-04-16 08:00:00, 2019-04-17 08:00:00]|17 |117      |6  |109      |1.07        |6          |
# |[2019-04-15 08:00:00, 2019-04-16 08:00:00]|17 |195      |6  |181      |1.08        |6          |
# |[2019-04-14 08:00:00, 2019-04-15 08:00:00]|17 |117      |6  |108      |1.08        |5          |
# |[2019-04-13 08:00:00, 2019-04-14 08:00:00]|17 |195      |6  |180      |1.08        |5          |
# |[2019-04-12 08:00:00, 2019-04-13 08:00:00]|17 |312      |6  |288      |1.08        |5          |
# |[2019-04-11 08:00:00, 2019-04-12 08:00:00]|17 |1876     |6  |289      |6.49        |1570       |
# |[2019-04-10 08:00:00, 2019-04-11 08:00:00]|17 |17804    |6  |302      |58.95       |15540      |
# |[2019-04-09 08:00:00, 2019-04-10 08:00:00]|17 |1728     |6  |293      |5.9         |1421       |
# |[2019-04-08 08:00:00, 2019-04-09 08:00:00]|17 |117      |6  |108      |1.08        |5          |
# |[2019-04-07 08:00:00, 2019-04-08 08:00:00]|17 |1610     |6  |183      |8.8         |1422       |
# |[2019-04-06 08:00:00, 2019-04-07 08:00:00]|17 |316      |6  |290      |1.09        |12         |
# |[2019-04-05 08:00:00, 2019-04-06 08:00:00]|17 |316      |6  |290      |1.09        |12         |
# |[2019-04-04 08:00:00, 2019-04-05 08:00:00]|17 |1563     |6  |291      |5.37        |1257       |
# |[2019-04-03 08:00:00, 2019-04-04 08:00:00]|17 |7074     |6  |296      |23.9        |6480       |
# |[2019-04-02 08:00:00, 2019-04-03 08:00:00]|17 |311      |6  |288      |1.08        |5          |
# |[2019-04-01 08:00:00, 2019-04-02 08:00:00]|17 |117      |6  |108      |1.08        |5          |
# |[2019-03-31 08:00:00, 2019-04-01 08:00:00]|17 |195      |6  |182      |1.07        |6          |
# |[2019-03-30 08:00:00, 2019-03-31 08:00:00]|17 |117      |6  |109      |1.07        |6          |
# |[2019-03-29 08:00:00, 2019-03-30 08:00:00]|17 |195      |6  |181      |1.08        |6          |
# |[2019-03-28 08:00:00, 2019-03-29 08:00:00]|17 |119      |6  |109      |1.09        |5          |
# |[2019-03-27 08:00:00, 2019-03-28 08:00:00]|17 |195      |6  |180      |1.08        |5          |
# |[2019-03-26 08:00:00, 2019-03-27 08:00:00]|17 |312      |6  |288      |1.08        |5          |
# |[2019-03-25 08:00:00, 2019-03-26 08:00:00]|17 |221      |6  |205      |1.08        |6          |
# +------------------------------------------+---+---------+---+---------+------------+-----------+

# %%
final.agg(corr('udp_tcp_rate', 'dport_count').alias('correlation')).show()
# Out:
# +------------------+
# |       correlation|
# +------------------+
# |0.9956992096398456|
# +------------------+

# %%
#output = final.repartition(1)
#output = output.toPandas()
#output = output.sort_values('window',ascending=False)
#output.to_excel('BC1C8115ABCD.xlsx',header=True,index=False)
